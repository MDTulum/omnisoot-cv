# %%
# %cd C:\Users\MehranDadsetan\Downloads\CRECK vs ABF (Santi)\creck
import os
os.getcwd()
# Out:
# C:\Users\MehranDadsetan\Downloads\CRECK vs ABF (Santi)\creck
# 'C:\\Users\\MehranDadsetan\\Downloads\\CRECK vs ABF (Santi)\\creck'

# %%
# !ck2yaml \
  --input CRECK_2003_TOT_HT_SOOT.CKI \
  --thermo CRECK_2003_TOT_HT_SOOT.CKT \
  --transport CRECK_2003_TOT_HT_SOOT.TRC \
  --output creck_soot_mechanism.yaml
# Out:
# Wrote YAML mechanism file to 'creck_soot_mechanism.yaml'.
# Mechanism contains 452 species and 24041 reactions.
# Validating mechanism...
# PASSED
